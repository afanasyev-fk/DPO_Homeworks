# %% [markdown]
# # Первый computational notebook

# %% [markdown]
# ## Упражнение: Вычисление числа pi с помощью метода Монте-Карло

# %% [markdown]
# Каждый пронумерованный элемент будет представлять собой новую ячейку. Нажмите `SHIFT
# +ENTER`, чтобы запустить ячейку и создать новую ячейку ниже. Выбрав ячейку, нажмите
# `ESCAPE` для перехода в командный режим. Используйте клавиши `M` и `Y` для изменения ячеек
# на разметку и код.

# %% [markdown]
# # Вычисление числа Пи с помощью метода Монте - Карло

# %% [markdown]
# ## Формулы
#
# - Площадь квадрата: $S = (2 r)^2$
# - Площадь круга: $C = \pi r^2$
# - $C/S = (\pi r^2) / (4 r^2) = \pi / 4$
# - $\pi = 4 * C/S$

# %% [markdown]
# ![Дротики](https://raw.githubusercontent.com/coderefinery/jupyter/main/example/darts.svg)

# %%
import random
import matplotlib.pyplot as plt

# %%
num_points = 1000

# %%
points = []
hits = 0 
for _ in range(num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x,y,"red"))
    else:
        points.append((x,y,"blue"))

# %%
x, y, colors = zip(*points)

fig, ax = plt.subplots() 
fig.set_size_inches(6.0, 6.0)

ax.scatter(x,y, c = colors)

fraction = hits / num_points
print("Pi = ", 4* fraction)
# Out:
# Pi =  3.116

# %% [markdown]
# ## Блокноты и контроль версий

# %% [markdown]
# ### Упражнение: что происходит без `requirements.txt`?

# %%
# !python -m pip install pandas matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/fyodor/.local/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/fyodor/.local/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: numpy>=1.26.0 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !python -m pip install pandas matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/fyodor/.local/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/fyodor/.local/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: seaborn in /home/fyodor/.local/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !python3 -m pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/fyodor/.local/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: matplotlib in /home/fyodor/.local/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (3.8.4)
# Requirement already satisfied: seaborn in /home/fyodor/.local/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fyodor/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fyodor/.local/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)

# %% [markdown]
# ### Консольные команды, виджеты оболочки и немного магии (cell magic)

# %%
from matplotlib import pyplot
import random
from ipywidgets import interact, widgets

# %matplotlib inline

def throw_darts(num_points):
    points = []
    hits = 0
    for _ in range(num_points):
        x, y = random.random(), random.random()
        if x*x + y*y < 1.0:
            hits += 1
            points.append((x, y, True))
        else:
            points.append((x, y, False))
    fraction = hits / num_points
    pi = 4 * fraction
    return pi, points


def create_plot(points):
    x, y, colors = zip(*points)
    pyplot.scatter(x, y, c=colors)


def experiment(num_points):
    pi, points = throw_darts(num_points)
    create_plot(points)
    print("approximation:", pi)

# %%
interact(experiment, num_points=widgets.IntSlider(min=100, max=10000, step=100, value=1000))
# Out:
# interactive(children=(IntSlider(value=1000, description='num_points', max=10000, min=100, step=100), Output())…
# <function __main__.experiment(num_points)>

# %% [markdown]
# ### Виджеты для интерактивной подгонки данных (data fitting)

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


def gaussian(x, a, b, c):
    return a * np.exp(-b * (x-c)**2)


def noisy_gaussian():
    # gaussian array y in interval -5 <= x <= 5
    nx = 100
    x = np.linspace(-5.0, 5.0, nx)
    y = gaussian(x, a=2.0, b=0.5, c=1.5)
    noise = np.random.normal(0.0, 0.2, nx)
    y += noise
    return x, y


def fit(x, y, n):
    pfit = np.polyfit(x, y, n)
    yfit = np.polyval(pfit, x)
    return yfit


def plot(x, y, yfit):
    plt.plot(x, y, "r", label="Data")
    plt.plot(x, yfit, "b", label="Fit")
    plt.legend()
    plt.ylim(-0.5, 2.5)
    plt.show()


x, y = noisy_gaussian()
yfit = fit(x, y, n=5)  # fit a 5th order polynomial to it
plot(x, y, yfit)

# %% [markdown]
# ### Профилирование ячеек

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def step():
    return 1 if random.random() > .5 else -1

# %%
def walk(n):
    x = np.zeros(n)
    dx = 1 / n
    for i in range(n - 1):
        x_new = x[i] + dx * step()
        if x_new > 5e-3:
            x[i + 1] = 0
        else:
            x[i + 1] = x_new
    return x

# %%
n = 100000
x = walk(n)
plt.plot(x)
t1 = %timeit -o walk(n)
# %prun walk(n)
# %lprun -f walk walk(10000)
# Out:
# 23.2 ms ± 262 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# UsageError: Line magic function `%lprun` not found.
#          200140 function calls (200137 primitive calls) in 0.047 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.029    0.029    0.046    0.046 1491881381.py:1(walk)
#     99999    0.011    0.000    0.017    0.000 24835620.py:1(step)
#     99999    0.006    0.000    0.006    0.000 {method 'random' of '_random.Random' objects}
#       2/1    0.000    0.000    0.046    0.046 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:607(_handle_events)
#         2    0.000    0.000    0.000    0.000 attrsettr.py:65(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 attrsettr.py:42(__getattr__)
#         1    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#         1    0.000    0.000    0.046    0.046 <string>:1(<module>)
#        12    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#         1    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         7    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#         3    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#         1    0.000    0.000    0.000    0.000 base_events.py:767(call_at)
#     26/24    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 typing.py:392(inner)
#         1    0.000    0.000    0.000    0.000 asyncio.py:200(call_at)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:687(_rebuild_io_state)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:648(_handle_recv)
#         1    0.000    0.000    0.000    0.000 events.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:743(call_later)
#         3    0.000    0.000    0.000    0.000 base_events.py:734(time)
#         2    0.000    0.000    0.000    0.000 typing.py:1285(__hash__)
#         7    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#         1    0.000    0.000    0.000    0.000 events.py:86(_run)
#         1    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         1    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 ioloop.py:584(call_later)
#         1    0.000    0.000    0.000    0.000 asyncio.py:190(_handle_events)
#         1    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 typing.py:1221(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 typing.py:1492(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:580(_run_callback)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.000    0.000    0.000    0.000 base_events.py:1894(_add_callback)
#         2    0.000    0.000    0.000    0.000 ioloop.py:529(time)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:710(_update_handler)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#         1    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#         1    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:2004(get_debug)
#         1    0.000    0.000    0.000    0.000 typing.py:2182(cast)

# %% [markdown]
# ### Установка команды для профилирования строк

# %%
import numpy as np
import matplotlib.pyplot as plt


def step():
    import random
    return 1. if random.random() > .5 else -1.


def walk(n):
    x = np.zeros(n)
    dx = 1. / n
    for i in range(n - 1):
        x_new = x[i] + dx * step()
        if x_new > 5e-3:
            x[i + 1] = 0.
        else:
            x[i + 1] = x_new
    return x


n = 100000
x = walk(n)

# %%
# %pip install line_profiler
# %load_ext line_profiler
# %lprun
# %lprun -f walk walk(10000)
# %lprun -f step walk(10000)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: line_profiler in /home/fyodor/.local/lib/python3.12/site-packages (4.1.3)
# Note: you may need to restart the kernel to use updated packages.
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# Timer unit: 1e-09 s
#
# Total time: 0.0165759 s
# File: /tmp/ipykernel_55422/20568004.py
# Function: step at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      5                                           def step():
#      6      9999    3351819.0    335.2     20.2      import random
#      7      9999   13224066.0   1322.5     79.8      return 1. if random.random() > .5 else -1.
